# %% [markdown]
# This notebook is meant to discover the library LightGraphs that will be used for the project, as well as get a little experience in manipulating graphs.

# %%
using LightGraphs
using GraphPlot
using Colors

# %% [markdown]
# Read the Graphs.jl tutorial that works with LightGraphs.jl instead of Graphs.jl: https://nbviewer.org/github/JuliaGraphs/JuliaGraphsTutorials/blob/master/Basics.ipynb
#
# **Question 0**: Explain how the graph from Out[20] of the tutorial was made, that is to say how its vertices and edges were defined.

# %% [markdown]
# Look at the help for function **inneighbors**.

# %%
# help for function inneighbors

# %% [markdown]
# Here is a simple graph that will be used to test the functions you code in this notebook.

# %%
toulouse_neigh = barabasi_albert(1000, 1)
# Out:
# {1000, 999} undirected simple Int64 graph

# %% [markdown]
# Function **gplot** allows to plot a graph, with **nodefillc** a vector giving the color of each vertex.

# %%
nodecolor = [colorant"lightseagreen"]
gplot(toulouse_neigh,nodefillc=nodecolor)
# Out:
# Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), Compose.UnitBox{Float64, Float64, Float64, Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.15463236603510971cx, -0.036847883042303964cy), (0.11658686394852208cx, 0.025928446378694455cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.16660495398405611cx, -0.04291415897335504cy), (0.516765770271147cx, -0.0120251814948531cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.1603167246332578cx, -0.0358640598767281cy), (0.22318891380927192cx, 0.27098393939477cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.1514861910585018cx, -0.040441907904628815cy), (0.016622128816129803cx, 0.018521032476590038cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.15622260545229824cx, -0.036111267512061986cy), (0.0618679186406749cx, 0.24604497659977745cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.16218126348621748cx, -0.03649634978356721cy), (0.23211381764718791cx, 0.10761682464538504cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.1513752663541912cx, -0.0407088121765891cy), (-0.24252643225953677cx, 0.11461362807414714cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.16355698891848966cx, -0.049869733818373556cy), (0.18450054001159946cx, -0.077033829574802cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.1620635765620705cx, -0.05077726914753036cy), (0.3020070488090717cx, -0.351692939802028cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.16659023340239756cx, -0.0444539752786215cy), (0.20046999639920435cx, -0.04809661608606063cy)])  …  Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.7272923539921129cx, -0.09370137119544447cy), (0.7779947573082541cx, -0.09924315990925175cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.2352228867022779cx, 0.5126505685952579cy), (-0.2643706101130782cx, 0.5539770509812726cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.6663953739261376cx, 0.07771008055412067cy), (0.7189551262622066cx, 0.07231445443277805cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.04669161511635286cx, -0.1763683317879353cy), (-0.08644755084444425cx, -0.1998475859292889cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.009251608350569545cx, 0.7305006892109653cy), (-0.01794081223604221cx, 0.7775523306797156cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.47008185603012653cx, -0.39817344564783425cy), (0.47313572935952464cx, -0.3468812979565659cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tup ...

# %% [markdown]
# **Question 1**: Write function **mean_degree** that computes the mean degree of the vertices of a graph. What is the mean degree of vertices of *toulouse_neigh* ? (expected answer: 1.998).

# %%
function mean_degree(graph)
    """Compute the mean degree of a graph
    
    PARAMS
        graph (LightGraphs): graph
    
    RETURN
        mean_degree (Float64): mean degree of vertices of graph"""
    2 * ne(graph) / nv(graph)
end
# Out:
# mean_degree (generic function with 1 method)

# %%
# test on toulouse_neigh
mean_degree(toulouse_neigh)
# Out:
# 1.998

# %% [markdown]
# **Question 2**: Write a function **random_simple_graph** that creates a simple graph with m vertices and n edges. It must throw an error if too much edges are asked for the number of vertices.

# %%
function random_simple_graph(graph, m, n)
    """Create a random simple graph with m vertices and n edges
    A test must throw an error if there is too much edges for the number of vertices
    
    PARAMS
        graph (LightGraphs): graph
        m (Int64): number of vertices of the graph to create
        n (Int64): number of edges of the graph to create
    
    RETURN
        G (LightGraphs): random simple graph with m vertices and n edges"""
    return graph(m, n)
end
# Out:
# random_simple_graph (generic function with 1 method)

# %%
# test random_simple_graph here
gplot(random_simple_graph(Graph, 5, 6))
# Out:
# Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), Compose.UnitBox{Float64, Float64, Float64, Float64}(-1.2, -1.2, 2.4, 2.4, 0.0mm, 0.0mm, 0.0mm, 0.0mm), nothing, nothing, nothing, List([Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.LinePrimitive}(Compose.LinePrimitive[Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.03664784893725995cx, 0.4651736852386168cy), (0.755412596579265cx, 0.03567102528733404cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.03200855014720676cx, 0.5621371096666247cy), (0.8970773009258602cx, 0.9563317275897697cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.21104160604330086cx, 0.4365712574115981cy), (-0.9238896431780457cx, -0.3304797915674407cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.8696063996606496cx, 0.0930414012483617cy), (0.984089597202702cx, 0.8893344720211948cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(0.7847225830171709cx, -0.10561655925963044cy), (0.15262799110166964cx, -0.9120075674708131cy)]), Compose.LinePrimitive{Tuple{Measures.Measure, Measures.Measure}}(Tuple{Measures.Measure, Measures.Measure}[(-0.01462881738600795cx, -0.9467048375765328cy), (-0.901716605358503cx, -0.46567253383570417cy)])], Symbol(""))]), List([Compose.Property{Compose.LineWidthPrimitive}(Compose.LineWidthPrimitive[Compose.LineWidthPrimitive(1.3416407864998738mm)]), Compose.Property{Compose.FillPrimitive}(Compose.FillPrimitive[Compose.FillPrimitive(RGBA{Float64}(0.0,0.0,0.0,0.0))]), Compose.Property{Compose.StrokePrimitive}(Compose.StrokePrimitive[Compose.StrokePrimitive(RGBA{Float64}(0.8274509803921568,0.8274509803921568,0.8274509803921568,1.0))])]), 0, false, false, false, false, nothing, nothing, 0.0, Symbol("")), Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([]), List([]), List([Compose.Property{Compose.LineWidthPrimitive}(Compose.LineWidthPrimitive[Compose.LineWidthPrimitive(1.3416407864998738mm)]), Compose.Property{Compose.StrokePrimitive}(Compose.StrokePrimitive[Compose.StrokePrimitive(RGBA{Float64}(0.8274509803921568,0.8274509803921568,0.8274509803921568,1.0))])]), 0, false, false, false, false, nothing, nothing, 0.0, Symbol("")), Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([]), List([]), List([Compose.Property{Compose.FontSizePrimitive}(Compose.FontSizePrimitive[Compose.FontSizePrimitive(4.0mm)]), Compose.Property{Compose.StrokePrimitive}(Compose.StrokePrimitive[Compose.StrokePrimitive(RGBA{Float64}(0.0,0.0,0.0,0.0))]), Compose.Property{Compose.FillPrimitive}(Compose.FillPrimitive[Compose.FillPrimitive(RGBA{Float64}(0.0,0.0,0.0,1.0))])]), 0, false, false, false, false, nothing, nothing, 0.0, Symbol("")), Compose.Context(Measures.BoundingBox{Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}, Tuple{Measures.Length{:w, Float64}, Measures.Length{:h, Float64}}}((0.0w, 0.0h), (1.0w, 1.0h)), nothing, nothing, nothing, nothing, List([]), List([Compose.Form{Compose.CirclePrimitive{Tuple{Measures.Measure, Measures. ...

# %% [markdown]
# **Question 3**: Write function **connected_comp** that computes the connected components of a graph. Hint: you can start by a function computing the connected component of a vertex s of the graph. How many connected components does *toulouse_neigh* have ? (expected answer : 1)

# %%
function connected_comp(graph)
    """Compute the connected components of a graph
    
    PARAMS
        graph (LightGraphs): graph
    
    RETURN
        component_list (Array{Int64,1}): list with each element the set of vertices indices
            of g that compose the connected component"""
    # TODO
end
# Out:
# connected_comp (generic function with 1 method)

# %%
# test on toulouse_neigh

# %% [markdown]
# Test **connected_comp** on a non connected graph of your choice.

# %%
# test on a non connected graph

# %% [markdown]
# It is the end of this little tutorial on graphs. You can start the project on the notebook **graph21-22**
